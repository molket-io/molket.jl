# %%
# Load MolKet's modules and libraries
#include("../molket.jl")
include("../molket.jl-main/molket.jl")
# Out:
# Load quantum gates constructor
# Load Tensor module: QTensor.jl
# Load quantum gates constructor
# Load quantum_circuit constructor
# Load quantum_circuit constructor
# Load quantum gates constructor
# Load Tensor module: QTensor.jl
# Load quantum gates constructor
# Load quantum_circuit constructor
# Load quantum gates constructor
# Load Tensor module: QTensor.jl
# Load quantum gates constructor
# Load quantum_circuit constructor
# Load quantum gates constructor
# Load Tensor module: QTensor.jl
# Load quantum gates constructor
# Load quantum_circuit constructor
# Load quantum_circuit constructor
# Load quantum_circuit constructor
# Load quantum_circuit constructor
# Load quantum_circuit constructor

# %% [markdown]
# First, we would like to calculate the harmonic potential of the symmetric stretch vibrational mode of $\text{CO}_2$ molecule.
#
# Vibrational frequency of the symmetric stretch mode of $\text{CO}_2$ is 1333
# $\text{cm}^{-1}$. (Reference: NIST database, https://webbook.nist.gov/cgi/cbook.cgi?ID=B4000020&Mask=800)
#
# The Harmonic oscillator Hamiltonian in a second quantized form is given by:
# $ \hat{H} = \hbar \omega \left( \hat{a}^{\dagger} \hat{a} + \frac{1}{2} \right) $ where $\hbar$ is the reduced Planck constant and $\omega$ is the vibrational frequency.
#
# The terms $\hat{a}^{\dagger}$ and $\hat{a}$ are the creation and annihilation operators, respectively.

# %% [markdown]
# ##### Mapping this particular Hamiltonian to a qubit Hamiltonian.
#
# Let's assume that we have 2 qubits to represent the vibrational mode. We express each vibrational level as a boson state $|n_i \rangle$ in the range $(0 \le n_i \le N_b)$.
# We maps this number state to a qubit system state of $N_b + 1$ qubits using a tensor
# product of qubit states:
#
# $$
# \begin{aligned}
# \left|n_i\right\rangle \leftrightarrow & \left|0_0 \cdots 0_{n_i-1} 1_{n_i} 0_{n_i+1} \cdots 0_{N_b}\right\rangle \\
# & =|0\rangle_0 \otimes \cdots \otimes|0\rangle_{n_i-1} \otimes|1\rangle_{n_i} \otimes|0\rangle_{n_i+1} \otimes \cdots \otimes|0\rangle_{N_b}
# \end{aligned}
# $$
# where
# $$
# |0\rangle_j=\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right),|1\rangle_j=\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right),
# $$
# are computation basis states of qubit $j$.

# %% [markdown]
# Hence, according to the formula, the state $|n_i\rangle$ = $|2_i\rangle$ at site $i$ is represented by:
# $$
# |2_i\rangle=|0\rangle_0 \otimes |0\rangle_1 \otimes |1\rangle_2
# $$
# If we use the binary mapping, the state number $n_i$ is represented by the binary number $b_i$ of $N_b$ bits.
#
# $$
# \left|n_i\right\rangle \leftrightarrow |011 \cdots 101\rangle
# $$
# $$
# \begin{aligned}
# \left|n_i\right\rangle \leftrightarrow & |\underbrace{011 \cdots 101}_{\text {binary rep. of } n_i}\rangle \\
# = & |0\rangle_1 \otimes|1\rangle_2 \otimes|1\rangle_3 \otimes \cdots \\
# & \otimes|1\rangle_{N_q-2} \otimes|0\rangle_{N_q-1} \otimes|1\rangle_{N_q} .
# \end{aligned}
# $$
#
# For example, the state $|2_i\rangle$ is represented by the binary number
# $|2 \rangle = |1\rangle_{N_{(q = 2)} - 1} \otimes |0\rangle_{N_{(q = 2)}}  $
#  leading to $|10\rangle$.

# %% [markdown]
# Now, we construct the matrix elements of the ladder operators $\hat{a}^{\dagger}$ and $\hat{a}$ in the qubit basis.
#
# $$
# \begin{aligned}
# & \mathbf{I}_i=\left(\begin{array}{ccccc}
# 1 & 0 & 0 & \cdots & 0 \\
# 0 & 1 & 0 & \cdots & 0 \\
# 0 & 0 & 1 & \cdots & 0 \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# 0 & 0 & 0 & \cdots & 1
# \end{array}\right) \\
# & =I_1 \otimes I_2 \otimes \cdots \otimes I_{N_q}, \\
# &
# \end{aligned}
# $$

# %% [markdown]
# We will consider the following Hamiltonian:
#
# $$
# \hat{H} = \hbar \omega \left( \hat{a}^{\dagger} \hat{a} + \frac{1}{2} \right)
# + V_{anharmonic}
# $$
#
# The additional terms are the cubic and quartic anharmonic terms, they correct the potential energy surface of the molecule of interest which is the symmetric stretch of $\text{CO}_2$.
#
# $$  V_{anharmonic} = g_1 \tilde{Q} + t_{111} \tilde{Q}^3 + u_{1111} \tilde{Q}^4 $$
#
# The coefficients are taken from the paper: J. Chem. Phys. 126, 124303 (2007); doi: 10.1063/1.2710256:
#
# | Coefficient | Value | unit |
# | --- | --- | --- |
# | $g_1$ | $-484.9598 \times 10^{-6}$ | au=$E_h$ |
# | $t_{111}$ | $203.2777 \times 10^{-6}$ | au = $E_h$ |
# | $u_{1111}$ | $8.3825 \times 10^{-6}$ | au = $E_h$ |
#
# These coefficients can be obtained from the paper: J. Chem. Phys. 126, 124303 (2007); doi: 10.1063/1.2710256:
#
# | Coefficient | Value | unit |
# | --- | --- | --- |
# | $g_1$ | $-0.0030609$ | $E_{h}$ $\AA^{-1} u^{-1/2}$ |
# | $t_{111}$ | $0.30667$ | $E_{h}$ $\AA^{-3} u^{-3/2}$ |
# | $u_{1111}$ | $0.31927$ | $E_{h}$ $\AA^{-4} u^{-2}$ |
#
# The conversion took place as
#
# ``` Julia
# println("unit: ", unit)
#
# g1_constantEh = g1_constant*unit/sqrt_m_omegs
# t111_constantEh = (1/6)*t111_constant*unit^3/sqrt_m_omegs^3
# u1111_constantEh = (1/24)*u1111_constant*unit^4/sqrt_m_omegs^4
#
# ```

# %%
N = 4
# test Qcan function for each order 
unit = 1/(Ang*sqrt(amu))
mu = 1 # due to the assumption of dimensionless units
c_constant = -0.0030609
h_constant = 0.24379

# convert the constants to a.u. 
c_constant = c_constant*unit
h_constant = h_constant*unit^2
omega = sqrt(h_constant/mu)
println("omega = ", omega/cm1, " cm^-1")

sqrt_m_omegs = sqrt(mu*omega)
println("sqrt_m_omegs = ", sqrt_m_omegs)

g1_constant = -0.0030609
t111_constant = 0.30667
u1111_constant = 0.31927

# convert the constants to a.u.
g1_constantEh = g1_constant*unit/sqrt_m_omegs
t111_constantEh = (1/6)*t111_constant*unit^3/sqrt_m_omegs^3
u1111_constantEh = (1/24)*u1111_constant*unit^4/sqrt_m_omegs^4

V_anharmonic = g1_constantEh*Qcan_p1(N) + (1/6)*t111_constantEh*Qcan_p3(N) 
               + u1111_constantEh*Qcan_p4(N)/4
# Out:
# omega = 1343.1154739418596 cm^-1
# sqrt_m_omegs = 0.07822841160624372
# 4×4 Matrix{ComplexF64}:
#  0.0+0.0im         0.0+0.0im         0.0+0.0im         0.0+0.0im
#  0.0+0.0im         0.0+0.0im         0.0+0.0im  5.13321e-6+0.0im
#  0.0+0.0im         0.0+0.0im  6.28687e-6+0.0im         0.0+0.0im
#  0.0+0.0im  5.13321e-6+0.0im         0.0+0.0im  1.88606e-5+0.0im

# %%
N = 4
npoints = 175
Qgrid = range(-5,stop=5,length=npoints)

qnum = [0,1,2,3]

V_anharmonic = g1_constantEh*Qcan_p1(N) + (1/6)*t111_constantEh*Qcan_p3(N) 
               + u1111_constantEh*Qcan_p4(N)/4
Hmat = H_harm(N;omega=omega)+  V_anharmonic

H_1D = H_ho1D(Hmat,qnum,Qgrid)
# print wavefunctions 
#println("Wavefunctions: ", H_1D.WFs)
# print the wfs in a table
show(stdout, "text/plain", real.(H_1D.WFs))
# Out:
# 175×4 Matrix{Float64}:
#  8.40301e-7   -2.32592e-6   -1.07175e-5   -0.000381707
#  1.09154e-6   -3.06941e-6   -1.4404e-5    -0.00048994
#  1.41328e-6   -4.03716e-6   -1.92688e-5   -0.000626501
#  1.82392e-6   -5.29248e-6   -2.5659e-5    -0.000798109
#  2.34625e-6   -6.91513e-6   -3.40141e-5   -0.00101288
#  3.00843e-6   -9.00532e-6   -4.48884e-5   -0.00128057
#  3.8451e-6    -1.16883e-5   -5.89768e-5   -0.00161284
#  4.89872e-6   -1.51203e-5   -7.71469e-5   -0.00202357
#  6.22116e-6   -1.94947e-5   -0.000100475  -0.00252916
#  7.87551e-6   -2.50509e-5   -0.000130292  -0.00314889
#  9.93827e-6   -3.2083e-5    -0.000168231  -0.00390531
#  1.25018e-5   -4.09517e-5   -0.000216289  -0.00482461
#  1.56774e-5   -5.20966e-5   -0.000276891  -0.00593704
#  1.95983e-5   -6.60521e-5   -0.000352973  -0.00727731
#  2.44239e-5   -8.34641e-5   -0.000448061  -0.00888496
#  3.03436e-5   -0.000105111  -0.000566373  -0.0108047
#  3.75825e-5   -0.000131924  -0.000712923  -0.013087
#  4.64063e-5   -0.000165017  -0.000893636  -0.0157877
#  5.71279e-5   -0.000205712  -0.00111548   -0.0189689
#  7.01145e-5   -0.000255571  -0.00138658   -0.0226985
#  8.57951e-5   -0.000316434  -0.00171639   -0.0270504
#  0.00010467   -0.000390454  -0.00211579   -0.032104
#  0.000127318  -0.00048014   -0.00259727   -0.0379435
#  0.000154412  -0.000588402  -0.00317503   -0.0446578
#  0.000186724  -0.000718597  -0.00386513   -0.0523385
#  0.00080192    0.00699641   -0.0393834     0.154963
#  0.000660659   0.00598102   -0.0342941     0.137065
#  0.000542053   0.00509432   -0.0297395     0.120675
#  0.000442901   0.0043233    -0.0256844     0.105759
#  0.000360375   0.00365566   -0.0220924     0.09227
#  0.000291988   0.00307994   -0.0189263     0.0801429
#  0.000235568   0.00258554   -0.0161491     0.0693033
#  0.000189227   0.00216269   -0.0137247     0.0596688
#  0.000151335   0.00180251   -0.0116182     0.0511522
#  0.000120491   0.00149694   -0.00979642    0.043664
#  9.54998e-5    0.00123873   -0.00822806    0.0371141
#  7.53427e-5    0.00102141   -0.00688396    0.0314144
#  5.91608e-5    0.000839219  -0.00573717    0.0264794
#  4.62313e-5    0.000687082  -0.00476304    0.0222273
#  3.59499e-5    0.000560533  -0.00393917    0.0185816
#  2.78141e-5    0.000455677  -0.00324539    0.0154705
#  2.14078e-5    0.000369129  -0.00266365    0.0128283
#  1.63889e-5    0.000297966  -0.00217793    0.0105945
#  1.24772e-5    0.000239677  -0.00177407    0.00871469
#  9.44444e-6    0.000192114  -0.00143968    0.00713995
#  7.10594e-6    0.00015345   -0.00116395    0.00582664
#  5.31281e-6    0.000122138  -0.000937515   0.0047362
#  3.9458e-6     9.68758e-5   -0.000752328   0.00383477
#  2.90989e-6    7.65705e-5   -0.000601485   0.00309282
#  2.12978e-6    6.03103e-5   -0.000479111   0.00248475
#  1.54614e-6    4.73377e-5   -0.000380228   0.00198853
#  1.1125e-6     3.70263e-5   -0.000300646   0.00158529
#  7.92659e-7    2.88604e-5   -0.00023685    0.00125898
#  5.586e-7      2.24174e-5   -0.000185909   0.000996027
#  3.88758e-7    1.73524e-5   -0.000145393   0.000785001
#  2.66646e-7    1.33853e-5   -0.000113293   0.000616343
#  1.79741e-7    1.02895e-5   -8.79597e-5    0.000482096
#  1.18596e-7    7.88235e-6   -6.80441e-5    0.000375672

# %%
# plot the wavefunctions    
plot(Qgrid,H_1D.WFs[:,1],label="qnum = 0")

plot!(Qgrid,H_1D.WFs[:,2],label="qnum = 1")

plot!(Qgrid,H_1D.WFs[:,3],label="qnum = 2")

plot!(xlabel="Q",ylabel="WF",title="Harmonic Oscillator Wavefunctions")

# %%
qnum = [0,1,2,3]
# Out:
# 4-element Vector{Int64}:
#  0
#  1
#  2
#  3

# %%
# creating a function for training 

function train_HO(N::Int64,omega::Float64,g1_constant::Float64,t111_constant::Float64,u1111_constant::Float64)
    # convert the constants to a.u.
    sqrt_m_omegs = sqrt(mu*omega)
    g1_constantEh = g1_constant*unit/sqrt_m_omegs
    t111_constantEh = (1/6)*t111_constant*unit^3/sqrt_m_omegs^3
    u1111_constantEh = (1/24)*u1111_constant*unit^4/sqrt_m_omegs^4

    V_anharmonic = g1_constantEh*Qcan_p1(N) + (1/6)*t111_constantEh*Qcan_p3(N) 
                   + u1111_constantEh*Qcan_p4(N)/4
    Hmat = H_harm(N;omega=omega) + V_anharmonic

    H_1D = H_ho1D(Hmat,qnum,Qgrid)
    return H_1D
end
# Out:
# train_HO (generic function with 1 method)

# %% [markdown]
# Now, the training could be done with respect to the following parameters:
#
# | Parameter | Value | unit |
# | --- | --- | --- |
# | $\omega$ | $1333$ | $\text{cm}^{-1}$ |
# | $g_1$ | $-484.9598 \times 10^{-6}$ | au=$E_h$ |
# | $t_{111}$ | $203.2777 \times 10^{-6}$ | au = $E_h$ |
# | $u_{1111}$ | $8.3825 \times 10^{-6}$ | au = $E_h$ |
#
# First, we can keep everything fixed and vary only the omega. We train the resulted wavefunctions with respect to the $\omega$ parameter at each $n$ state. Hence, at any random Omega, the AI model should be able to predict the wavefunction of the system.
#
#
# $\omega$ is the vibrational frequency of the symmetric stretch mode of $\text{CO}_2$ molecule. The training could be done with respect to the following values of $\omega$:
#
# 800 cm$^-1$ < $\omega$ < 1600 cm$^-1$ in steps of 100 cm$^-1$.

# %%
# test the function
N = 4
omega = sqrt(h_constant/mu)
g1_constant = -0.0030609
t111_constant = 0.30667
u1111_constant = 0.31927


# train the model
H_1D = train_HO(N,omega,g1_constant,t111_constant,u1111_constant)
# print wavefunctions
#println("Wavefunctions: ", H_1D.WFs)
# print the wfs in a table
show(stdout, "text/plain", real.(H_1D.WFs))
# Out:
# 175×4 Matrix{Float64}:
#  8.40301e-7   -2.32592e-6   -1.07175e-5   -0.000381707
#  1.09154e-6   -3.06941e-6   -1.4404e-5    -0.00048994
#  1.41328e-6   -4.03716e-6   -1.92688e-5   -0.000626501
#  1.82392e-6   -5.29248e-6   -2.5659e-5    -0.000798109
#  2.34625e-6   -6.91513e-6   -3.40141e-5   -0.00101288
#  3.00843e-6   -9.00532e-6   -4.48884e-5   -0.00128057
#  3.8451e-6    -1.16883e-5   -5.89768e-5   -0.00161284
#  4.89872e-6   -1.51203e-5   -7.71469e-5   -0.00202357
#  6.22116e-6   -1.94947e-5   -0.000100475  -0.00252916
#  7.87551e-6   -2.50509e-5   -0.000130292  -0.00314889
#  9.93827e-6   -3.2083e-5    -0.000168231  -0.00390531
#  1.25018e-5   -4.09517e-5   -0.000216289  -0.00482461
#  1.56774e-5   -5.20966e-5   -0.000276891  -0.00593704
#  1.95983e-5   -6.60521e-5   -0.000352973  -0.00727731
#  2.44239e-5   -8.34641e-5   -0.000448061  -0.00888496
#  3.03436e-5   -0.000105111  -0.000566373  -0.0108047
#  3.75825e-5   -0.000131924  -0.000712923  -0.013087
#  4.64063e-5   -0.000165017  -0.000893636  -0.0157877
#  5.71279e-5   -0.000205712  -0.00111548   -0.0189689
#  7.01145e-5   -0.000255571  -0.00138658   -0.0226985
#  8.57951e-5   -0.000316434  -0.00171639   -0.0270504
#  0.00010467   -0.000390454  -0.00211579   -0.032104
#  0.000127318  -0.00048014   -0.00259727   -0.0379435
#  0.000154412  -0.000588402  -0.00317503   -0.0446578
#  0.000186724  -0.000718597  -0.00386513   -0.0523385
#  0.000225141  -0.000874575  -0.00468559   -0.0610793
#  0.000270678  -0.00106073   -0.00565645   -0.0709739
#  0.000542053   0.00509432   -0.0297395     0.120675
#  0.000442901   0.0043233    -0.0256844     0.105759
#  0.000360375   0.00365566   -0.0220924     0.09227
#  0.000291988   0.00307994   -0.0189263     0.0801429
#  0.000235568   0.00258554   -0.0161491     0.0693033
#  0.000189227   0.00216269   -0.0137247     0.0596688
#  0.000151335   0.00180251   -0.0116182     0.0511522
#  0.000120491   0.00149694   -0.00979642    0.043664
#  9.54998e-5    0.00123873   -0.00822806    0.0371141
#  7.53427e-5    0.00102141   -0.00688396    0.0314144
#  5.91608e-5    0.000839219  -0.00573717    0.0264794
#  4.62313e-5    0.000687082  -0.00476304    0.0222273
#  3.59499e-5    0.000560533  -0.00393917    0.0185816
#  2.78141e-5    0.000455677  -0.00324539    0.0154705
#  2.14078e-5    0.000369129  -0.00266365    0.0128283
#  1.63889e-5    0.000297966  -0.00217793    0.0105945
#  1.24772e-5    0.000239677  -0.00177407    0.00871469
#  9.44444e-6    0.000192114  -0.00143968    0.00713995
#  7.10594e-6    0.00015345   -0.00116395    0.00582664
#  5.31281e-6    0.000122138  -0.000937515   0.0047362
#  3.9458e-6     9.68758e-5   -0.000752328   0.00383477
#  2.90989e-6    7.65705e-5   -0.000601485   0.00309282
#  2.12978e-6    6.03103e-5   -0.000479111   0.00248475
#  1.54614e-6    4.73377e-5   -0.000380228   0.00198853
#  1.1125e-6     3.70263e-5   -0.000300646   0.00158529
#  7.92659e-7    2.88604e-5   -0.00023685    0.00125898
#  5.586e-7      2.24174e-5   -0.000185909   0.000996027
#  3.88758e-7    1.73524e-5   -0.000145393   0.000785001
#  2.66646e-7    1.33853e-5   -0.000113293   0.000616343
#  1.79741e-7    1.02895e-5   -8.79597e-5    0.000482096
#  1.18596e-7    7.88235e-6   -6.80441e-5    0.000375672

# %%
#include("MK_neural_surrogates.jl")
include("../molket.jl-main/MK_neural_surrogates.jl")
# Out:
# Main.MK_neural_surrogates

# %%
import .MK_neural_surrogates: Param, run_surrogate

# %% [markdown]
# ### Setup param data structure

# %%
param = Param()
# Out:
# Param(Main.MK_neural_surrogates.var"#2#4"(), false, [0, 1, 2, 3], 175, -5.0:0.05747126436781609:5.0, 0, 1200.0, -0.0030609, 0.30667, 0.31927, 0.7, false, 1.0e-5, 800.0, 1600.0, 10, 40000, 40000, 1, 0.01, 0.1, "model.jld2")

# %%
#-----------------------------------------------------
# Setup function zerofy! that chops off small numbers
#-----------------------------------------------------
function zerofy!(x, vmin)
    for (i, val) in enumerate(x)
        if abs(val) < vmin
            x[i] = zero(eltype(x))
        end
    end
end

#------------------------------------------------------------------------------------------------------------------------------------------
# Setup function f that computes a matrix of Wavefunctions given omega
# The vec() is an inbuilt function in julia which is used to reshape the specified array as a one-dimensional column vector i.e, 1D array.
# https://www.geeksforgeeks.org/reshaping-array-as-a-vector-in-julia-array-vec-method/
#------------------------------------------------------------------------------------------------------------------------------------------
function f(omega::Float64; param::Param=param)

    # Retrieve parameters from param data structure
    verbose1 = param.verbose1
    qnum = param.qnum
    npoints = param.npoints
    n = param.n
    g1_constant = param.g1_constant
    t111_constant = param.t111_constant
    u1111_constant = param.u1111_constant
    shift = param.shift
    zerofy = param.zerofy 
    vmin = param.vmin
    
    N = size(qnum)[1]
    
    n = max(0,n) + 1
    n = min(n, N)
    
    # convert the constants to a.u.
    sqrt_m_omegs = sqrt(mu*omega)
    g1_constantEh = g1_constant*unit/sqrt_m_omegs
    t111_constantEh = (1/6)*t111_constant*unit^3/sqrt_m_omegs^3
    u1111_constantEh = (1/24)*u1111_constant*unit^4/sqrt_m_omegs^4

    V_anharmonic = g1_constantEh*Qcan_p1(N) + (1/6)*t111_constantEh*Qcan_p3(N) 
                   + u1111_constantEh*Qcan_p4(N)/4
    
    Hmat = H_harm(N;omega=omega) + V_anharmonic

    Qgrid = range(-5,stop=5,length=npoints)
    H_1D = H_ho1D(Hmat,qnum,Qgrid)
    WFs = real.(H_1D.WFs)[:,n]
    
    for (i, val) in enumerate(WFs)
        WFs[i] += shift
    end

    m = maximum(WFs)
    if m > 1.0
        WFs = (1.0/m).*WFs
    end

    if zerofy
        zerofy!(WFs, vmin)
    end
    
    return vec(WFs)
end
# Out:
# f (generic function with 1 method)

# %%
param.f = f
# Out:
# f (generic function with 1 method)

# %% [markdown]
# ### omega = 400

# %%
neural, x, y = run_surrogate(; param=param, omega=400.0, n=0, shift=0.0908, grad=0.1, verbose1=true)
" "
# Out:
# Building a neural surrogate function that predicts the wavefunctions
# ┌ Warning: Layer with Float32 parameters got Float64 input.
# │   The input will be converted, but any earlier layers may be very slow.
# │   layer = Dense(1 => 20, σ)   # 40 parameters
# │   summary(x) = "1-element Vector{Float64}"
# └ @ Flux ~/.julia/packages/Flux/Mhg1r/src/layers/stateless.jl:60
# build_surrogate - delta = euclidean(model(x), y[1]): 0.00014489626358983436
#
# Saving neural model state in file: model_400.0_0.jld2
#
# No optimization needed since delta: 0.00014489626358983436 is less than target: 0.01
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.00014489626358983436
#
# neural(x):
#  Vector{Float32}:
#  0.090813965
#  0.09080808
#  0.09081339
#  0.090811834
#  0.090815045
#  0.090816446
#  0.09081424
#  0.090820104
#  0.09081442
#  0.090821624
#  0.09081997
#  0.09082226
#  0.09082619
#  0.090825245
#  0.090833336
#  0.09083682
#  0.09084054
#  0.09084749
#  0.09085558
#  0.090866216
#  0.09087919
#  0.090898864
#  0.0909179
#  0.09093784
#  0.09096972
#  0.09100214
#  0.09104683
#  0.09109771
#  0.0911612
#  0.09123511
#  0.09131943
#  0.09142592
#  0.091547385
#  0.09169715
#  0.09186176
#  0.092058845
#  0.09229333
#  0.09255842
#  0.09286923
#  0.09322293
#  0.09363433
#  0.09410302
#  0.094637714
#  0.09524163
#  0.09592667
#  0.09668757
#  0.097560205
#  0.09852739
#  0.099600166
#  0.100778975
#  0.10209793
#  0.1035439
#  0.10513941
#  0.10685789
#  0.10873935
#  0.110773645
#  0.11296365
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.04957449449647437
#
#
# Plot with omega = 400.0, n = 2, y[1]
# Plot with omega = 400.0, n = 2, neural surrogate
# " "

# %%
neural, x, y = run_surrogate(; param=param, omega=400.0, n=3, shift=0.74, grad=0.08, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.049565603104749084
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.049565603104749084
#
#
# Plot with omega = 400.0, n = 3, y[1]
# Plot with omega = 400.0, n = 3, neural surrogate
# " "

# %% [markdown]
# ### omega = 800

# %%
neural, x, y = run_surrogate(; param=param, omega=800.0, n=0, shift=0.0908, grad=0.1, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.000130601938443474
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.000130601938443474
#
#
# Plot with omega = 800.0, n = 0, y[1]
# Plot with omega = 800.0, n = 0, neural surrogate
# " "

# %%
neural, x, y = run_surrogate(; param=param, omega=800.0, n=2, shift=0.8, grad=0.08, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.05250158993400193
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.05250158993400193
#
#
# Plot with omega = 800.0, n = 2, y[1]
# Plot with omega = 800.0, n = 2, neural surrogate
# " "

# %%
neural, x, y = run_surrogate(; param=param, omega=800.0, n=3, shift=0.74, grad=0.08, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.051106361719445985
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.051106361719445985
#
#
# Plot with omega = 800.0, n = 3, y[1]
# Plot with omega = 800.0, n = 3, neural surrogate
# " "

# %% [markdown]
# ### omega = 1200

# %%
neural, x, y = run_surrogate(; param=param, omega=1200.0, n=0, shift=0.0908, grad=0.1, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.0001622193820376664
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.0001622193820376664
#
#
# Plot with omega = 1200.0, n = 0, y[1]
# Plot with omega = 1200.0, n = 0, neural surrogate
# " "

# %%
neural, x, y = run_surrogate(; param=param, omega=1200.0, n=1, shift=0.8, grad=0.08, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.0007910042784345689
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.0007910042784345689
#
#
# Plot with omega = 1200.0, n = 1, y[1]
# Plot with omega = 1200.0, n = 1, neural surrogate
# " "

# %%
neural, x, y = run_surrogate(; param=param, omega=1200.0, qnum=[0, 1, 2, 3, 4], n=5, shift=0.8, grad=0.08, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.06372594485941434
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.06372594485941434
#
#
# Plot with omega = 1200.0, n = 5, y[1]
# Plot with omega = 1200.0, n = 5, neural surrogate
# " "

# %% [markdown]
# ### omega = 1500

# %%
neural, x, y = run_surrogate(; param=param, omega=1500.0, n=0, shift=0.0908, grad=0.1, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.00012868108881842474
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.00012868108881842474
#
#
# Plot with omega = 1500.0, n = 0, y[1]
# Plot with omega = 1500.0, n = 0, neural surrogate
# " "

# %%
neural, x, y = run_surrogate(; param=param, omega=1500.0, n=1, shift=0.8, grad=0.08, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.0009541665090730357
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.0009541665090730357
#
#
# Plot with omega = 1500.0, n = 1, y[1]
# Plot with omega = 1500.0, n = 1, neural surrogate
# " "

# %%
neural, x, y = run_surrogate(; param=param, omega=1500.0, qnum=[0, 1, 2, 3, 4], n=5, shift=0.8, grad=0.08, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.06501396954812967
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.06501396954812967
#
#
# Plot with omega = 1500.0, n = 5, y[1]
# Plot with omega = 1500.0, n = 5, neural surrogate
# " "

# %% [markdown]
# ### omega = 1800

# %%
neural, x, y = run_surrogate(; param=param, omega=1800.0, n=0, shift=0.0908, grad=0.1, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.00013630530756177054
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.00013630530756177054
#
#
# Plot with omega = 1800.0, n = 0, y[1]
# Plot with omega = 1800.0, n = 0, neural surrogate
# " "

# %%
neural, x, y = run_surrogate(; param=param, omega=1800.0, n=1, shift=0.8, grad=0.08, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.0007971072106744849
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.0007971072106744849
#
#
# Plot with omega = 1800.0, n = 1, y[1]
# Plot with omega = 1800.0, n = 1, neural surrogate
# " "

# %%
neural, x, y = run_surrogate(; param=param, omega=1800.0, qnum=[0, 1, 2, 3, 4], n=5, shift=0.8, grad=0.08, verbose1=false)
" "
# Out:
# build_surrogate - delta = euclidean(model(x), y[1]): 0.06552577211495206
#
# neural_surrogate - delta = euclidean(model(x), y[1]): 0.06552577211495206
#
#
# Plot with omega = 1800.0, n = 5, y[1]
# Plot with omega = 1800.0, n = 5, neural surrogate
# " "

# %%
# Display Julia version information
versioninfo()
# Out:
# Julia Version 1.11.2
# Commit 5e9a32e7af2 (2024-12-01 20:02 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#   CPU: 16 × AMD Ryzen 7 6800H with Radeon Graphics
#   WORD_SIZE: 64
#   LLVM: libLLVM-16.0.6 (ORCJIT, znver3)
# Threads: 1 default, 0 interactive, 1 GC (on 16 virtual cores)
